# %%
# %matplotlib inline 
from __future__ import division
from pylab import *
import skimage as ski
from skimage import data, io, filters, exposure
from skimage.filters import rank
from skimage import img_as_float, img_as_ubyte
from skimage.morphology import disk
import skimage.morphology as mp
from skimage import util
from skimage.color import rgb2hsv, hsv2rgb, rgb2gray
from skimage.filters.edges import convolve
from matplotlib import pylab as plt
import numpy as np
from numpy import array
from IPython.display import display
from ipywidgets import interact, interactive, fixed
from ipywidgets import *
from ipykernel.pylab.backend_inline import flush_figures
import cv2

# %%
def disp (names):
    fig = figure(figsize=(36, 35))
    for i, name in enumerate(names):
        subplot(3, 2, i+1)
        samolot = cv2.imread(name)
        samolotGray = cv2.cvtColor(samolot, cv2.COLOR_BGR2GRAY) 
        blur = cv2.GaussianBlur(samolotGray,(5,5),0)
        ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
        edges = cv2.Canny(th3,200, 255)
        im = io.imshow(edges, cmap = 'gray')
        plt.axis('off')
        
    fig.savefig('samoloty6.pdf')

if __name__ == '__main__':
    names = ['samolot01.jpg', 'samolot07.jpg', 'samolot08.jpg', 'samolot09.jpg', 'samolot10.jpg', 'samolot17.jpg']
    disp(names)
# Out:
# D:\Programy\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "
